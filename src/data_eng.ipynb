# %%
import os
import json
from pprint import pprint
import pandas as pd

# %%
base_data_path = '../data/'
total_jsons = len(os.listdir(os.path.join(base_data_path, 'jsons')))
print(f'Total JSON files: {total_jsons}')
# Out:
# Total JSON files: 102

# %%
with open(os.path.join(base_data_path, 'jsons', '6.json'), 'rb') as f:
    tmp_json_data = json.load(f)
pprint(tmp_json_data) # doc_judgement
# Out:
# {'doc_bench': 'Bench: B.S. Chauhan, J. Chelameswar, M.Y. Eqbal',
#  'doc_judgement': ['M.Y. EQBAL, J.:',
#                    '1.  These appeals have been filed against  the  common  '
#                    'judgment  and  order\n'
#                    '    dated 21.12.2000 passed by Delhi High Court in L.P.A. '
#                    'Nos. 4, 43,  139,\n'
#                    '    148 of 1987, 21 of 1988, 77 of 1993 and  86  of  '
#                    '1994.    By  the  said\n'
#                    '    judgment,  the  High  Court  allowed  the  appeals  '
#                    'preferred  by   the\n'
#                    '    respondents and quashed not only their termination '
#                    'orders but also  the\n'
#                    '    General Court Martial (hereinafter referred to  as  '
#                    '‘GCM’)  proceedings\n'
#                    '    held against Captain Ashok Kumar Rana and Captain R.S. '
#                    'Rathaur.',
#                    '2.  Before we proceed with the matter, it would be '
#                    'appropriate to  highlight\n'
#                    '    the factual background and brief history of the case.',
#                    'In February 1971, Gunner Sarwan Dass was cultivated  by  '
#                    'Pakistan\n'
#                    '    Intelligence. In 1972 Captain Ghalwat and Gunner  '
#                    'Sarwan  Dass  crossed\n'
#                    '    the international border. In 1973 Captain  Ghalwat  '
#                    'and  Gunner  Sarwan\n'
#                    '    Dass were posted in  Babina  (M.P.).  In  1974  '
#                    'Gunner  Aya  Singh  was\n'
#                    '    cultivated by Gunner Sarwan Dass for Pak '
#                    'Intelligence.  Captain  Nagial\n'
#                    '    was then cultivated by Aya Singh for Pak Intelligence. '
#                    'In 1975 for  the\n'
#                    '    first time the espionage racket came  to  be  '
#                    'noticed.  Aya  Singh  and\n'
#                    '    Sarwan Dass were arrested. In 1976-77 pursuant  to  '
#                    'the  investigation,\n'
#                    '    three more jawans were arrested. They corroborated '
#                    'the  involvement  of\n'
#                    '    Sarwan Dass.  Sarwan  Dass  and  Aya  Singh  on  '
#                    'further  interrogation\n'
#                    '    disclosed the names of Captain Ghalwat and Captain '
#                    'Nagial.  In  1976-77\n'
#                    '    Captain  Ghalwat  and  Captain  Nagial  were  tried  '
#                    'by  GCM  and  were\n'
#                    '    convicted. Ghalwat was cashiered and given 14  years’  '
#                    'RI.  Nagial  was\n'
#                    '    given 7 years’ RI and was also cashiered. In addition, '
#                    '12  jawans  were\n'
#                    '    tried and they were given RI of various descriptions '
#                    'and were dismissed\n'
#                    '    from services. Aya Singh and Sarwan Dass were also '
#                    'among the 12  jawans\n'
#                    '    tried and held guilty. Later in 1978 it was discovered '
#                    'that  Aya  Singh\n'
#                    '    was holding back certain relevant  information  '
#                    'relating  to  espionage\n'
#                    '    activities under certain alleged threat and pressure. '
#                    'Wife of Aya Singh\n'
#                    '    claimed to be killed. Reeling under the shock of the '
#                    'circumstances,  he\n'
#                    '    made further disclosures wherein he named Captain '
#                    'Rathaur  and  Captain\n'
#                    '    A.K. Rana; disclosed that he had been  receiving  '
#                    'threats  that  if  he\n'
#                    '    disclosed anything his wife  would  be  killed.  '
#                    'Accordingly,  in  1978\n'
#                    '    Captain Rathaur and Captain A.K. Rana were '
#                    'interrogated.  As a  result,\n'
#                    '    42 army personnel i.e. 19  officers,  4  junior  '
#                    'commissioned  officers\n'
#                    '    (JCOs) and 19 other ranks (ORs), were arrested.',
#                    'Out of the 19 officers, 3 officers were tried by  GCM,   '
#                    'two  were\n'
#                    '    convicted, namely, Captain Ranbir Singh Rathaur and '
#                    'Captain A.K.  Rana,\n'
#                    '    and one was acquitted. Captain Ranbir Singh Rathaur  '
#                    'and  Captain  A.K.\n'
#                    '    Rana were sentenced to RI for 14 years each and were '
#                    'cashiered. Against\n'
#                    '    13 officers, disciplinary actions were initiated. '
#                    'However,  a  decision\n'
#                    '    was taken not to try them and an administrative order '
#                    'under Section  18\n'
#                    '    of the Army Act, 1950 (in short “the Army Act”) was '
#                    'passed  terminating\n'
#                    '    their services.',
#                    '3.  The present appeals arise out of the  order  passed  '
#                    'way  back  in  1980\n'
#                    '    terminating the services of the respondents herein '
#                    'which  were  brought\n'
#                    '    invoking the doctrine of pleasure as enshrined under '
#                    'Article 310 of the\n'
#                    '    Constitution  of  India,  1950  (hereinafter   '
#                    'referred   to   as   the\n'
#                    '    ‘Constitution’) coupled with the powers to be '
#                    'exercised  under  Section\n'
#                    '    18 of the Army Act.  Initially, the orders of '
#                    'dismissal were passed  on\n'
#                    '    11.1.1980, which  were  assailed  in  nine  writ  '
#                    'petitions  that  were\n'
#                    '    dismissed by the High Court of Delhi on 21.4.1980.  '
#                    'The  special  leave\n'
#                    '    petitions against these writ petitions came to  be  '
#                    'dismissed  by  this\n'
#                    '    Court on 1.9.1980.',
#                    '4.  In the meanwhile, a corrigendum came to be issued, as '
#                    'a result  whereof,\n'
#                    '    the orders of dismissal were described as  orders  of  '
#                    'termination.  On\n'
#                    '    account of the substituted  termination order, a '
#                    'decision for deducting\n'
#                    '    5% of the gratuity amount was taken,  which  was  '
#                    'communicated  afresh.\n'
#                    '    These orders made a fresh ground of challenge before '
#                    'a  learned  Single\n'
#                    '    Judge of the Delhi High Court.  The learned Single '
#                    'Judge dismissed  the\n'
#                    '    petition by a detailed judgment dated 22.3.1985.   '
#                    'Simultaneously,  one\n'
#                    '    Captain R.S. Rathaur had filed a Writ Petition '
#                    'No.1577  of  1985  under\n'
#                    '    Article 32 of the Constitution before this Court, '
#                    'which stood dismissed\n'
#                    '    refusing to re-open the issues already decided.',
#                    '5.  Against the order of the learned Single Judge dated  '
#                    '22.3.1985,  several\n'
#                    '    Letters Patent Appeals were filed.   One  of  the  '
#                    'appeals,  being  LPA\n'
#                    '    No.116 of 1985, filed by one N.D. Sharma,  was  '
#                    'decided  vide  judgment\n'
#                    '    dated 19.8.1986  upholding  the  order  of  '
#                    'termination  approving  the\n'
#                    '    applicability of the doctrine of pleasure.  However, '
#                    'at the same  time,\n'
#                    '    the appeal was partly allowed in relation to the '
#                    'post-retiral  benefits\n'
#                    '    keeping in view the provisions under the Army Act and '
#                    'Rules and it  was\n'
#                    '    found that the proposed 5% cut-off  was  not  in  '
#                    'accordance  with  the\n'
#                    '    Act/Rules applicable therein.',
#                    '6.  Several LPAs were filed by other officers relying on '
#                    'the Division  Bench\n'
#                    '    judgment extending the post-retiral benefits, and a  '
#                    'plea  for  similar\n'
#                    '    relief was raised.',
#                    '7.  When these appeals came up for hearing, the Division '
#                    'Bench of the  Delhi\n'
#                    '    High Court hearing the matter differed with the view '
#                    'on  the  issue  of\n'
#                    '    the applicability of doctrine of pleasure and  '
#                    'maintainability  of  the\n'
#                    '    writ petitions on the ground of malafides vide order  '
#                    'dated  15.5.1991.\n'
#                    '    Consequently, this question of law was referred  to  '
#                    'be  decided  by  a\n'
#                    '    larger bench.',
#                    '8.  The Full Bench so constituted to answer  this  '
#                    'reference  held  that  an\n'
#                    '    order under Section 18  of  the  Army  Act  invoking  '
#                    'the  doctrine  of\n'
#                    '    pleasure  was  subject  to  judicial   review  if  it  '
#                    'is  assailed  on\n'
#                    '    malafides.  It was held that the  onus  lay  on  the  '
#                    'petitioner/person\n'
#                    '    alleging malafides and to bring material on record to '
#                    'satisfy the court\n'
#                    '    in order to justify the interference.  Aggrieved, the  '
#                    'Union  of  India\n'
#                    '    filed the Special Leave Petition, which stood '
#                    'dismissed.',
#                    '9.   It appears that after the answer  of  reference,  '
#                    'the  pending  appeals\n'
#                    '    were taken up for decision by the High Court.  On '
#                    'account of the answer\n'
#                    '    given by the Full Bench, fresh petitions were filed '
#                    'by  those  officers\n'
#                    '    whose petitions had been dismissed earlier upto this '
#                    'Court as  referred\n'
#                    '    to hereinabove, in 1980.  Some writ petitioners,  '
#                    'whose  petitions  had\n'
#                    '    been dismissed by learned Single Judge, filed  '
#                    'Letters  Patent  Appeals\n'
#                    '    with applications for condonation of delay.  Appeals  '
#                    'were  also  filed\n'
#                    '    against those  judgments  that  were  given  in  the  '
#                    'second  round  of\n'
#                    '    litigation proposing to refuse 5% of the terminal '
#                    'benefits referred  to\n'
#                    '    hereinabove.  These categories  of  petitions  were  '
#                    'described  by  the\n'
#                    '    Division Bench hearing the matter in its order dated '
#                    '2.5.1995, as under\n'
#                    '    :-',
#                    '10. Thereafter two writ petitions that were filed  '
#                    'afresh,  namely,  in  the\n'
#                    '    case  of  Major  Subhash  Juneja  and  Harish  Lal  '
#                    'Singh,  were  heard\n'
#                    '    separately  and  dealt  with  the  principle  of   '
#                    'res   judicata   and\n'
#                    '    constructive res judicata.  The said writ petitions  '
#                    'were  held  to  be\n'
#                    '    barred by  law  vide  judgment  dated  8.3.1996.  The  '
#                    'other  connected\n'
#                    '    petitions also appeared to have been dismissed as not  '
#                    'maintainable  by\n'
#                    '    another Division Bench vide order dated 7.9.1992.',
#                    '11. The Letters Patent  Appeals  which  were  filed  with  '
#                    'applications  for\n'
#                    '    condonation of delay and also against the judgment '
#                    'proposing 5% cut-off\n'
#                    '    in the terminal benefits were heard  by  another  '
#                    'Division  Bench  that\n'
#                    '    reserved the judgment on 14.8.1998 by passing the '
#                    'following order:',
#                    '12.    The Division  Bench  that  went  on  to  reserve  '
#                    'the  said  judgment\n'
#                    '    delivered it after almost 3 years and allowed the '
#                    'appeals. Therein,  it\n'
#                    '    was held that the proceedings initiated against the '
#                    'writ petitioners as\n'
#                    '    also against other officers, who were appellants  in  '
#                    'the  other  LPAs,\n'
#                    '    were vitiated as there was no material to support the  '
#                    'impugned  orders\n'
#                    '    of termination which were camouflaged and thus, the '
#                    'same  were  subject\n'
#                    '    to judicial  review.  Accordingly, vide judgment dated '
#                    '21.12.2000,  the\n'
#                    '    relief of consequential benefits was granted after  '
#                    'setting  aside  the\n'
#                    '    order of termination.   The relevant part thereof is '
#                    'extracted herein:',
#                    '13. Another relevant event in this journey of  judicial  '
#                    'conflict  which  is\n'
#                    '    worth mentioning is that  two  officers,  namely,  '
#                    'Subhash  Juneja  and\n'
#                    '    Harish Lal Singh, whose writ petitions had been '
#                    'dismissed on the ground\n'
#                    '    of constructive res judicata, filed special leave '
#                    'petitions  that  were\n'
#                    '    converted to Civil Appeal Nos. 1931 and 1932 of 1997 '
#                    'and  were  finally\n'
#                    '    dismissed by a  three-Judge  Bench  of  this  Court  '
#                    'vide  order  dated\n'
#                    '    23.4.2003, which is quoted as under:',
#                    '15. The appeals filed by the Union  of  India,  pending  '
#                    'before  this  Court\n'
#                    '    against the judgment dated 21.12.2000, were split into '
#                    'two parts by the\n'
#                    '    order of this Court dated 14.2.2006, which is '
#                    'extracted herein:',
#                    '16. Accordingly, the arguments were heard and judgment was '
#                    'reserved  in  the\n'
#                    '    matter arising out of the two writ petitions  filed  '
#                    'by  Ranbir   Singh\n'
#                    '    Rathaur  and Ashok  Kumar  Rana  alongwith which '
#                    'delinked  seven   LPAs\n'
#                    '    were  also disposed of  even though it was  observed  '
#                    'by   this   Court\n'
#                    '    that  they   arose  out  of  the  same    incident.   '
#                    'This  Court  vide\n'
#                    '    judgment dated 22.3.2006 in   the case of Union of  '
#                    'India  &  Ors.  vs.\n'
#                    '    Ranbir Singh Rathaur & Ors.,  (2006) 11 SCC  696  '
#                    'reversed the judgment\n'
#                    '    of the High Court dated 21.12.2000 vis-a-vis the  two  '
#                    'writ   petitions\n'
#                    '    and held as follows:',
#                    '"  (Emphasis added)\n'
#                    '\n'
#                    '\n'
#                    'On remand, the High Court dismissed the writ petitions '
#                    'vide  judgment  dated\n'
#                    '20.12.2007 and the same has been placed on record by the '
#                    'appellants.',
#                    'So far these appeals are concerned, the High Court by  '
#                    'the  impugned  common\n'
#                    'order dated 21.12.2000, not only quashed the  termination  '
#                    'orders  but  also\n'
#                    'court martial proceedings held against some of the '
#                    'officers.',
#                    'The Division Bench of this Court, after hearing the  '
#                    'counsel  appearing  for\n'
#                    'the parties and legal contentions urged, formulated   the  '
#                    'following  points\n'
#                    'for consideration by a larger bench [Union of India vs. '
#                    'S.P. Sharma,  (2013)\n'
#                    '10 SCC 150]:-',
#                    '20. The learned Additional Solicitor General at the  very  '
#                    'outset  submitted\n'
#                    '    that issues involving security of the State were '
#                    'extremely complex  and\n'
#                    '    the issue related to  the  expediency  and  '
#                    'desirability  of  retaining\n'
#                    '    officers in the Army who had  become  security  '
#                    'suspects.  The  instant\n'
#                    '    cases of the respondent officers were examined at '
#                    'various levels in the\n'
#                    '    Army Headquarters as also in  the  Central  '
#                    'Government  and  the  final\n'
#                    '    decision to exercise the power to pass  an  order  of  '
#                    'termination  was\n'
#                    '    taken by it under Section 18 of the Army Act.  '
#                    'Learned  counsel  relied\n'
#                    '    upon the judgment of this Court in B.P. Singhal vs. '
#                    'Union  of  India  &\n'
#                    '    Ors. (2010) 6 SCC 331  and  contended  that  the  '
#                    'parameters  that  are\n'
#                    '    required to be taken into consideration for  exercise  '
#                    'of  power  under\n'
#                    '    Article 310 of the Constitution are varied. Several of '
#                    'these parameters\n'
#                    '    entail evaluation of issues relevant to the security '
#                    'of the State.  The\n'
#                    '    factors that form the basis of exercise of power under '
#                    'Article  310  of\n'
#                    '    the Constitution cannot be said to be  objective  '
#                    'parameters  that  are\n'
#                    '    amenable to judicially manageable standards. The '
#                    'reasons that form  the\n'
#                    '    basis of exercise of power under  Article  310  can  '
#                    'extend  to  varied\n'
#                    '    levels of subjective assessments and evaluations  in  '
#                    'entailing  expert\n'
#                    '    knowledge as to issues of security of the State. In '
#                    'that  view  of  the\n'
#                    '    matter it is submitted that exercise of power of '
#                    'judicial review  would\n'
#                    '    accord great latitude to the bona fide evaluation made '
#                    'by the competent\n'
#                    '    authorities in the course of discharge of the duties.  '
#                    'The  correctness\n'
#                    '    of the opinion formed or the sufficiency of material '
#                    'forming the  basis\n'
#                    '    of their decision  to  pass  an  order  of  '
#                    'termination  would  not  be\n'
#                    '    subjected to judicial scrutiny of either the High '
#                    'Court or this  Court.\n'
#                    '    Further, placing strong reliance upon B.P. Singhal '
#                    'case, (supra) it  is\n'
#                    '    contended by the learned Additional Solicitor General '
#                    'that exercise  of\n'
#                    '    power of judicial review under Article 310 is '
#                    'extremely narrow  and  is\n'
#                    '    limited to only one parameter, namely,  violation  of  '
#                    'fundamentals  of\n'
#                    '    constitutionalism. The standard of judicial review '
#                    'which applies to the\n'
#                    '    case of exercise of executive  or  statutory  or  '
#                    'quasi-judicial  power\n'
#                    '    cannot be extended to the case of  judicial  review  '
#                    'of  constitutional\n'
#                    '    power under Article 310. Learned counsel submitted '
#                    'that the  fact  that\n'
#                    '    Article 311 does not apply to the case of '
#                    'officers/employees  of  armed\n'
#                    '    forces, the power under  Article  309  also  cannot  '
#                    'be  exercised  for\n'
#                    '    limiting the ambit of Article 310. The Army Act is an  '
#                    'enactment  under\n'
#                    '    Article  309.  The  aforesaid  legal  principle   '
#                    'has   been   followed\n'
#                    '    consistently in  all  subsequent  decisions  of  this  '
#                    'Court.  In  this\n'
#                    '    connection learned counsel relied upon  the judgment '
#                    'of this  Court  in\n'
#                    '    Moti Ram Deka vs. North  East  Frontier  Railways  '
#                    '(1964)  5  SCR  683.\n'
#                    '    Further, the Constitution Bench of this Court in Ram '
#                    'Sarup vs. Union of\n'
#                    '    India,  AIR  1965  SC  247  with  reference  to  '
#                    'Article  33   of   the\n'
#                    '    Constitution, has laid down limitations provided on  '
#                    'the  applicability\n'
#                    '    of fundamental rights guaranteed to the '
#                    'officers/employees of the  Army\n'
#                    '    under Articles 14, 16 and 21 of the Constitution and '
#                    'under  Section  21\n'
#                    '    of the Army Act. He has further contended that each '
#                    'of  the  provisions\n'
#                    '    of the Army Act also carries the sanction  of  '
#                    'Parliament  against  the\n'
#                    '    applicability of all other fundamental rights '
#                    'contained under Part  III\n'
#                    '    of the Constitution to the extent to which the rights '
#                    'contained in  the\n'
#                    '    fundamental rights are inconsistent with the  '
#                    'provisions  of  the  Army\n'
#                    '    Act.  The  aforesaid  enunciation  of  law  has  '
#                    'again  been   followed\n'
#                    '    consistently by this Court in subsequent decisions.',
#                    '21. The learned Additional Solicitor General further  '
#                    'contended  that  in  a\n'
#                    '    matter of civilian employees, Article 311 represents a '
#                    'limitation  over\n'
#                    '    the absoluteness of pleasure doctrine contained in '
#                    'Article 310. In Moti\n'
#                    '    Ram Deka (supra)  and in the subsequent cases,  this  '
#                    'Court  laid  down\n'
#                    '    that Article 311 introduces a twofold procedural '
#                    'safeguard in favour of\n'
#                    '    an employee/officer in relation to the exercise of  '
#                    'pleasure  doctrine.\n'
#                    '    However, Article 311 applies  only  in  cases  of  '
#                    'punishment  and  not\n'
#                    '    otherwise. The  availability  of  the  safeguards  '
#                    'provided  for  under\n'
#                    '    Article 311 is contingent upon and limited to cases '
#                    'where the power  of\n'
#                    '    termination of services of an  employee/officer  is  '
#                    'exercised  by  the\n'
#                    '    disciplinary authority by  way  of  punishment.  The  '
#                    'applicability  of\n'
#                    '    Article 311 of the Constitution being dependent on '
#                    'the  factum  of  the\n'
#                    '    order of termination being in the  nature  of  a  '
#                    'punishment,  judicial\n'
#                    '    review undertaken in case of civilian employees '
#                    'entails  the  necessity\n'
#                    '    for and the power of determining as to whether the '
#                    'order impugned is in\n'
#                    '    the nature of a  punishment  or  not.  The  doctrine  '
#                    'of  “foundation”,\n'
#                    '    “camouflage” and the principles of judicial  review,  '
#                    'encompassing  the\n'
#                    '    necessity and the power of determining, whether the '
#                    'order  impugned  is\n'
#                    '    by way of a punishment  is  thus  a  direct  '
#                    'emanation  and  a  logical\n'
#                    '    corollary of the nature of enquiry warranted when '
#                    'Article  311  applies\n'
#                    '    to a case.',
#                    '22. Since the provisions of Article 311 of the  '
#                    'Constitution  admittedly  do\n'
#                    '    not apply to  these  cases,  it  relates  to  the  '
#                    'domain  of  civilian\n'
#                    '    employees/officers  service  jurisprudence,  which  '
#                    'is  controlled   by\n'
#                    '    Article 311, cannot be invoked in the  case  of  '
#                    'employees/officers  of\n'
#                    '    armed forces. Since the protection of Article 311 '
#                    'cannot be claimed  in\n'
#                    '    the case of employees of armed forces, no enquiry  as  '
#                    'to  whether  the\n'
#                    '    order is by way of  a  punishment,  which  is  the  '
#                    'sine  qua  non  for\n'
#                    '    applicability of Article 311, is warranted. The legal '
#                    'issue requires to\n'
#                    '    be considered by this Court in the context of the fact '
#                    'as to whether by\n'
#                    '    virtue of anything contained in the language  of  '
#                    'Article  310  or  the\n'
#                    '    other provisions of the Constitution, the  '
#                    'constitutional  power  under\n'
#                    '    Article 310 can be construed to be  limited  to  '
#                    'cases  of  termination\n'
#                    '    simpliciter. It is contended on behalf of the '
#                    'appellants  that  neither\n'
#                    '    the language of Article 310 nor any other provision of '
#                    'the Constitution\n'
#                    '    warrants adoption of such a narrow construction. '
#                    'Further,  the  learned\n'
#                    '    Additional  Solicitor  General  has  contended  that  '
#                    'this  Court   has\n'
#                    '    consistently held that the ambit of the doctrine of '
#                    'pleasure, contained\n'
#                    '    under Article 310, is an absolute power, save to  the  '
#                    'extent  provided\n'
#                    '    otherwise by an express provision of the Constitution. '
#                    'The only express\n'
#                    '    limitation on the power of Article 310 exists under '
#                    'the Constitution in\n'
#                    '    relation to the tenure of certain constitutional '
#                    'functionaries such  as\n'
#                    '    the Hon’ble Judges of the High Court and the Supreme '
#                    'Court. He  further\n'
#                    '    contends, placing reliance upon Moti Ram Deka (supra) '
#                    'that  this  Court\n'
#                    '    has laid down the legal principle; that the ambit  of  '
#                    'Article  310  is\n'
#                    '    circumscribed only by the provisions  of  Article  '
#                    '311  and  that  even\n'
#                    '    Article 309 does not circumscribe the said  power.  '
#                    'The  conferment  of\n'
#                    '    power upon the President of India under  Article  310  '
#                    'is  in  absolute\n'
#                    '    terms. Therefore, there is no basis for suggesting '
#                    'that the power under\n'
#                    '    Article 310 ought to be construed as excluding the '
#                    'power to dismiss  an\n'
#                    '    employee or officer for misconduct. The  very  fact  '
#                    'that  Article  310\n'
#                    '    makes the tenure subject to the  absolute  pleasure  '
#                    'of  the  President\n'
#                    '    means that the President can exercise the said power '
#                    'for any reason and\n'
#                    '    without assigning any cause or reason and this is  '
#                    'precisely  what  has\n'
#                    '    been laid down by this  Court  in  B.P.  Singhal  '
#                    '(supra).  He  further\n'
#                    '    contends that the power under Article 310 also '
#                    'encompasses the power to\n'
#                    '    dismiss an employee or  officer  for  misconduct  and  '
#                    'Article  311  is\n'
#                    '    inapplicable in respect of an employee or officer of '
#                    'the armed  forces.\n'
#                    '    It is further submitted that in case of armed  forces  '
#                    'scrutiny  of  an\n'
#                    '    order passed under Article 310 would neither warrant '
#                    'an enquiry  as  to\n'
#                    '    the foundation of the order nor an enquiry as to '
#                    'whether the  order  is\n'
#                    '    in the nature of punishment. Therefore, he submits '
#                    'that  the  necessary\n'
#                    '    corollary thereof would be that the competent '
#                    'authority is also free to\n'
#                    '    abandon any statutory procedure at any stage and  '
#                    'take  resort  to  the\n'
#                    '    constitutional power under Article 310 by the  '
#                    'President  to  terminate\n'
#                    '    the services of an employee/officer of the armed '
#                    'forces. The  ambit  of\n'
#                    '    such power cannot be circumscribed with reference to '
#                    'the concepts  that\n'
#                    '    govern  the  exercise  of   the   power   in   '
#                    'relation   to   civilian\n'
#                    '    employees/officers.',
#                    '23. Learned Additional Solicitor General  put  reliance  '
#                    'on  Chief  of  Army\n'
#                    '    Staff vs. Major Dharam Pal Kukrety, (1985) 2 SCC 412 '
#                    'where  this  Court\n'
#                    '    has also upheld the competent authority’s power to '
#                    'switch over  to  its\n'
#                    '    power under Section 18 of the Army Act  upon  '
#                    'abandonment  of  the  GCM\n'
#                    '    proceedings  against  its  employees/officers.  The   '
#                    'authorities   are\n'
#                    '    competent to take recourse to their statutory power '
#                    'under Section 19 in\n'
#                    '    a case where the court  martial  exercise  initiated  '
#                    'by  them  becomes\n'
#                    '    futile. It cannot be contended by the officer  that  '
#                    'where  alternative\n'
#                    '    powers under the statute can be resorted  to  in  '
#                    'such  situations  the\n'
#                    '    authority cannot resort to its constitutional power '
#                    'under  Article  310\n'
#                    '    but pass an order of termination against the officer '
#                    'of the Army.  Such\n'
#                    '    provision of the statutory power including Section 19 '
#                    'of the  Army  Act\n'
#                    '    can be said to be subject to the limitations of the '
#                    'scheme of the  Army\n'
#                    '    Act. Power under Article 310, which is constitutional '
#                    'power,  is  wider\n'
#                    '    and certainly cannot be subjected to the constraints '
#                    'flowing  from  the\n'
#                    '    scheme of the Army Act. It is further contended  that  '
#                    'this  Court  has\n'
#                    '    examined the legality and validity of similar orders '
#                    'of termination  in\n'
#                    '    exercise of  power  under  Article  310  of  the  '
#                    'Constitution  by  the\n'
#                    '    President upholding the orders of termination passed '
#                    'in exercise of the\n'
#                    '    aforesaid constitutional statutory provisions.',
#                    '24. Shri P.P. Rao, learned senior counsel  appearing  for  '
#                    'respondent  Major\n'
#                    '    S.P. Sharma, firstly brought to our notice the '
#                    'sequence of  the  events\n'
#                    '    happened so far as this respondent  is  concerned.   '
#                    'According  to  the\n'
#                    '    learned counsel in spite of unblemished career and '
#                    'academic  experience\n'
#                    '    Major Sharma was arrested in 1979 and was lodged  in  '
#                    'a  cell  and  was\n'
#                    '    denied the basic facilities.  The said respondent  '
#                    'represented  to  the\n'
#                    '    Chief of Army Staff and  Deputy  Chief  of  Army  '
#                    'Staff-GOC  about  the\n'
#                    '    inhuman treatment.  However, in 1979 a charge report '
#                    'was handed over to\n'
#                    '    the respondent on 14.04.1979 for which he was '
#                    'arrested.  It was alleged\n'
#                    '    by the respondent that the army authorities released '
#                    'false,  defamatory\n'
#                    '    and fabricated press release stating that the '
#                    'respondent was  the  ring\n'
#                    '    leader of the group with 15 others and was spying for '
#                    'Pakistan,  having\n'
#                    '    received huge sum in Indian currency  for  passing  '
#                    'of  information  to\n'
#                    '    Pakistan about the Indian Army.  A second charge '
#                    'report was handed over\n'
#                    '    to the respondent.  Later on a summary of evidence was '
#                    'commenced on the\n'
#                    '    basis of false allegation.',
#                    'Mr. Rao, then contended that  about  27  prosecution  '
#                    'witnesses\n'
#                    '    were examined and all of them spoke about his honesty '
#                    'and integrity and\n'
#                    '    uprightness.  Learned senior counsel submitted that  '
#                    'when  the  charges\n'
#                    '    against the present respondent were not substantiated '
#                    'he  was  released\n'
#                    '    from arrest and suspended from duties.  He was granted '
#                    'leave and  after\n'
#                    '    that he  was  recalled  for  duty  and  an  order  of  '
#                    'dismissal  dated\n'
#                    '    11.01.1980 was served and handed over to the '
#                    'respondent.  Subsequently,\n'
#                    '    by  a  corrigendum  the  order  of  dismissal  of  '
#                    'the  respondent  was\n'
#                    '    substituted by an order of termination.',
#                    '25. Mr. Rao, has not disputed the fact that the said '
#                    'respondent  Major  S.P.\n'
#                    '    Sharma filed a writ petition being W.P. No.418 of 1980 '
#                    'challenging  the\n'
#                    '    order of dismissal  dated  11.01.1980.   The  said  '
#                    'writ  petition  was\n'
#                    '    dismissed by a Division Bench of the Delhi High Court '
#                    'and  against  the\n'
#                    '    said order the respondent preferred a  Special  Leave  '
#                    'Petition  before\n'
#                    '    this Court being 7225 of 1980 which was also '
#                    'dismissed.  When the order\n'
#                    '    of dismissal attained finality, the respondent was '
#                    'served with  a  show\n'
#                    '    cause notice as to why a cut-off 5%  in  the  '
#                    'retirement  gratuity  and\n'
#                    '    Death-Cum-Retirement Gratuity be not imposed as  his  '
#                    'service  was  not\n'
#                    '    satisfactory.  The respondent Sharma again challenged '
#                    'the  said  notice\n'
#                    '    by filing a writ petition in the High Court being W.P. '
#                    'No.1643 of 1982.\n'
#                    '     In the said Writ Petition the respondent  also  '
#                    'challenged  the  order\n'
#                    '    dated 03.03.1980 by which the dismissal was '
#                    'substituted by an order  of\n'
#                    '    termination.  The said writ petition was dismissed by '
#                    'the High Court on\n'
#                    '    22.03.1985 holding that the said order of termination '
#                    'is a  termination\n'
#                    '    simpliciter without being any stigma  attached.   The  '
#                    'said  order  was\n'
#                    '    challenged by the respondent by filing LPA No.77 of '
#                    '1993.   The  matter\n'
#                    '    then travelled to a Full Bench and finally concluded  '
#                    'by  the  impugned\n'
#                    '    order passed by the Division Bench of the Delhi High '
#                    'Court.',
#                    '26. Mr. P.P. Rao, learned  senior  counsel  advanced  his  '
#                    'argument  on  the\n'
#                    '    points formulated by this Court and  submitted  that  '
#                    'the  second  writ\n'
#                    '    petition cannot, at any stretch of imagination, be '
#                    'held to be barred by\n'
#                    '    the principles of res judicata.  Learned counsel '
#                    'further submitted that\n'
#                    '    by issuing an order of termination in place of  '
#                    'dismissal,  the  entire\n'
#                    '    finding recorded by the Court while considering the '
#                    'order of  dismissal\n'
#                    '    got washed off, hence there can be no res judicata.',
#                    '27. Mr. Rao then drew our attention to the counter '
#                    'affidavit  filed  by  the\n'
#                    '    appellant Union of India before the High Court and  '
#                    'submitted  that  if\n'
#                    '    the offence was so grave then the respondent should '
#                    'have been  punished\n'
#                    '    instead of dismissal from service.',
#                    '28. Mr. Rao vehemently argued by giving reference to  the  '
#                    'finding  recorded\n'
#                    '    by the High Court that non-production  of  records  '
#                    'and  the  materials\n'
#                    '    which are the basis for passing the  order  of  '
#                    'termination  is  wholly\n'
#                    '    illegal, arbitrary and unjustified.  He reiterated '
#                    'that  for  the  non-\n'
#                    '    production of materials and records in spite of being '
#                    'directed  by  the\n'
#                    '    Court, adverse inference has to be drawn.   According  '
#                    'to  the  learned\n'
#                    '    senior  counsel,  withholding  of  documents  by   '
#                    'the   constitutional\n'
#                    '    authority and the Government is a serious matter  '
#                    'and,  therefore,  the\n'
#                    '    High Court has rightly held the order of termination '
#                    'bad  in  law.   In\n'
#                    '    this regard learned counsel referred and relied upon '
#                    'the  decisions  of\n'
#                    '    this Court in Gopal Krishnaji Ketkar  vs. Mahomed  '
#                    'Haji  Latif  &  Ors.\n'
#                    '    1968 (3) SCR 862 and Ghaio Mall & Sons  vs. State of '
#                    'Delhi & Ors., 1959\n'
#                    '    SCR 1424.',
#                    '29. On the question of doctrine of  pleasure,   Mr.  Rao  '
#                    'firstly  contended\n'
#                    '    that the constitutional provisions contained in '
#                    'Article  309,  310  and\n'
#                    '    311 are subject to Article  14 of the Constitution.  '
#                    'According  to  the\n'
#                    '    learned counsel, Article 14, 15 and 21 constitute the '
#                    'core  values  and\n'
#                    '    such right cannot be taken away on the plea of  '
#                    'doctrine  of  pleasure.\n'
#                    '    In this connection he relied on   I.R. Coelho    vs.   '
#                    'State  of  Tamil\n'
#                    '    Nadu,  (2007) 2 SCC 1.',
#                    '30. Mr. Rao then contended that Article 33 of the  '
#                    'Constitution  is  in  the\n'
#                    '    nature of exception but it does not abrogate  the  '
#                    'fundamental  rights.\n'
#                    '    In other words, Article 33 does not speak about the '
#                    'basic structure  of\n'
#                    '    the Constitution.  Learned counsel relied upon  the  '
#                    'decision  of  this\n'
#                    '    Court  in B.P. Singhal  vs.  U.O.I., (2010) 6 SCC 331.',
#                    '31. Mr. Rao then contended that Article 33  in  any  '
#                    'event  shall  be  given\n'
#                    '    restricted interpretation for the reason that any law  '
#                    'which  restricts\n'
#                    '    the  fundamental  rights  shall  be  strictly  '
#                    'interpreted.   In   this\n'
#                    '    connection learned counsel referred to (1974) 1 SCC '
#                    '645: Bhut Nath Mete\n'
#                    '    vs. State of West Bengal.   Mr.  Rao  addressed  on  '
#                    'legal  malice  and\n'
#                    '    malice in law and referred a decision of this Court  '
#                    'in  Ravi  Yashwant\n'
#                    '    Bhoir vs. District Collector, Raigad & Ors., (2012) 4 '
#                    'SCC 407.',
#                    '32. Mr. Rao submitted that only notings were produced '
#                    'before the High  Court\n'
#                    '    but the material on the basis of  which  opinion  was  '
#                    'formed  was  not\n'
#                    '    produced.  The detailed summary of evidence, different '
#                    'memos and  other\n'
#                    '    documents produced in  the  court  martial  '
#                    'proceeding  were  also  not\n'
#                    '    produced before the High Court.  Learned counsel '
#                    'submitted  that  those\n'
#                    '    notings produced  before  the  High  Court  are  not  '
#                    'material,  rather\n'
#                    '    advisory material.  Learned counsel referred to some '
#                    'of the  paragraphs\n'
#                    '    of the judgment rendered in S.R. Bommai and Ors.  vs.  '
#                    'Union  of  India\n'
#                    '    and Ors., (1994) 3 SCC 1.',
#                    'Learned  counsel  lastly  submitted  that  although  5%  '
#                    'cut  in\n'
#                    '    gratuity has been withdrawn by the appellant, the '
#                    'termination has to be\n'
#                    '    held as bad.',
#                    '33.   Mr. Deepak Bhattacharya, learned counsel appearing '
#                    'on behalf of  Major\n'
#                    '    Ajwani in C.A. No.2953 of 2001, firstly submitted  '
#                    'that  the  order  of\n'
#                    '    termination under Section 18 of the Army Act is a  '
#                    'colourable  exercise\n'
#                    '    of power which is  arbitrary,  capricious  and  '
#                    'unreasonable.   Learned\n'
#                    '    counsel submitted that the pleasure doctrine is the '
#                    'residual  executive\n'
#                    '    power under Section 53  of  the  Constitution  and  '
#                    'hence  amenable  to\n'
#                    '    judicial review to ensure that the same follows the '
#                    'satisfaction of the\n'
#                    '    President after due application of  mind  and  '
#                    'without  any  arbitrary,\n'
#                    '    capricious and un-reasonable  exercise  of  power.   '
#                    'According  to  the\n'
#                    '    learned counsel the respondent Major Ajwani was '
#                    'arrested  and  kept  in\n'
#                    '    solitary confinement without being informed of any '
#                    'reason for the  same\n'
#                    '    and, thereafter, criminal proceedings were initiated '
#                    'against  him.   It\n'
#                    '    was contended that the criminal proceedings against '
#                    'him  was  abandoned\n'
#                    '    without informing him any reason  for  the  same  and  '
#                    'finally  he  was\n'
#                    '    illegally terminated under Section 18 of the Army Act.',
#                    '34.         On the question of res judicata, learned '
#                    'counsel submitted  that\n'
#                    '    there is no pleading of res judicata  ever  raised  '
#                    'by  the  appellant.\n'
#                    '    However, learned counsel adopted the argument advanced '
#                    'by Mr. P.P.  Rao\n'
#                    '    on the question of res judicata.',
#                    '35.         Mrs. Kiran  Suri,  learned  counsel  '
#                    'appearing  for  Capt.  Arun\n'
#                    '    Sharma and Capt. J.S. Yadav in C.A.No.2954 of 2001 and '
#                    'C.A.No. 2957  of\n'
#                    '    2001, firstly submitted that there is  no  decision  '
#                    'on  merit  in  the\n'
#                    '    earlier writ petition and, therefore, the question  '
# ...
#                    '72.   In the case of Babu Singh Bains etc. versus Union of '
#                    'India and  others\n'
#                    '      etc., AIR 1997 SC 116, this Court reiterated the '
#                    'settled principal  of\n'
#                    '      law that once an order passed on merit by this  '
#                    'Court  exercising  the\n'
#                    '      power under Article 136 of the Constitution has '
#                    'become final  no  writ\n'
#                    '      petition under Article 32 of the Constitution on '
#                    'the  self-same  issue\n'
#                    '      is maintainable.  The principle of constructive res  '
#                    'judicata   stands\n'
#                    '      fast in his way in his way to raise the same '
#                    'contention once over.',
#                    '73.   In Khoday Distilleries  Limited  &  Anr.  vs.\xa0'
#                    'The  Registrar  General,\n'
#                    '      Supreme Court of India, (1996) 3 SCC 114, this '
#                    'Court  re-iterated  the\n'
#                    '      view as under:',
#                    '74.   In M. Nagabhushana vs. State of Karnataka & Ors., '
#                    'AIR  2011  SC  1113,\n'
#                    '      this Court held that doctrine of  res-judicata  was  '
#                    'not  a  technical\n'
#                    '      doctrine but a fundamental principle which sustains '
#                    'the rule of law in\n'
#                    '      ensuring finality in litigation. The main object of '
#                    'the doctrine is to\n'
#                    '      promote a fair administration of  justice  and  to  '
#                    'prevent  abuse  of\n'
#                    '      process of the court on the issues which have become '
#                    'final between the\n'
#                    '      parties. The doctrine was based on two  age  old  '
#                    'principles,  namely,\n'
#                    "      'interest reipublicae ut sit finis litium' which "
#                    'means that it  is  in\n'
#                    '      the interest of the State that there should be an  '
#                    'end  to  litigation\n'
#                    "      and the other principle is 'nemo debet bis vexari  "
#                    'si  constat  curiae\n'
#                    "      quod sit pro una et eadem causa' meaning thereby "
#                    'that no one ought  to\n'
#                    '      be vexed twice in a litigation if it appears to the '
#                    'Court that  it  is\n'
#                    '      for one and the same cause.',
#                    '75.   Thus, the principle of finality of litigation  is  '
#                    'based  on  a  sound\n'
#                    '      firm principle of public policy. In the absence of  '
#                    'such  a  principle\n'
#                    '      great oppression might result under the colour  and  '
#                    'pretence  of  law\n'
#                    '      inasmuch as there will be no end to litigation. The '
#                    'doctrine  of  res-\n'
#                    '      judicata has been evolved to prevent such an '
#                    'anarchy.',
#                    '76.    In a country governed by the rule of law,  '
#                    'finality  of  judgment  is\n'
#                    '      absolutely imperative and great sanctity is attached '
#                    'to  the  finality\n'
#                    '      of the judgment and it is not permissible for the  '
#                    'parties  to  reopen\n'
#                    '      the concluded judgments of the court as it would '
#                    'not  only  tantamount\n'
#                    '      to merely an abuse of the process of the  court  '
#                    'but  would  have  far\n'
#                    '      reaching adverse affect on the administration  of  '
#                    'justice.  It  would\n'
#                    '      also nullify the doctrine of stare decisis a well '
#                    'established valuable\n'
#                    '      principle of precedent which cannot be departed from '
#                    'unless there  are\n'
#                    '      compelling circumstances to do so. The  judgments  '
#                    'of  the  court  and\n'
#                    '      particularly the Apex Court of a country  cannot  '
#                    'and  should  not  be\n'
#                    '      unsettled lightly.',
#                    '77.  Precedent keeps the law  predictable  and  the  law  '
#                    'declared  by  this\n'
#                    '      Court, being the law of the land, is binding on  '
#                    'all  courts/tribunals\n'
#                    '      and authorities in India in view of Article 141 of  '
#                    'the  Constitution.\n'
#                    '      The judicial system "only works if someone is '
#                    'allowed to have the last\n'
#                    '      word" and  the  last  word  so  spoken  is  '
#                    'accepted  and  religiously\n'
#                    '      followed. The doctrine of  stare  decisis  promotes  '
#                    'a  certainty  and\n'
#                    '      consistency in judicial decisions and this helps in '
#                    'the development of\n'
#                    '      the law. Besides providing guidelines for '
#                    'individuals as to what would\n'
#                    '      be the consequences if he  chooses  the  legal  '
#                    'action,  the  doctrine\n'
#                    '      promotes confidence of the  people  in  the  system  '
#                    'of  the  judicial\n'
#                    '      administration. Even otherwise it is an imperative '
#                    'necessity to  avoid\n'
#                    '      uncertainty, confusion. Judicial propriety and '
#                    'decorum demand that the\n'
#                    '      law laid down by the highest Court of the land must  '
#                    'be  given  effect\n'
#                    '      to.',
#                    '78.   In Rupa Ashok Hurra v. Ashok Hurra & Anr.,  AIR  '
#                    '2002  SC  1771,  this\n'
#                    '      Court dealt with the issue and held that '
#                    'reconsideration of a judgment\n'
#                    '      of this Court which has attained finality is not '
#                    'normally permissible.\n'
#                    '      A decision  upon  a  question  of  law  rendered  '
#                    'by  this  Court  was\n'
#                    '      conclusive and would bind the court in  subsequent  '
#                    'cases.  The  court\n'
#                    '      cannot sit in appeal against its own judgment.',
#                    '79.   In Maganlal Chhaganlal (P) Ltd. v. Municipal  '
#                    'Corporation  of  Greater\n'
#                    '      Bombay, AIR 1974 SC 2009, this Court held as under:',
#                    'Thus, in view of above, it can be held that doctrine of  '
#                    'finality  has\n'
#                    '      to be applied in a strict legal sense.',
#                    '80. While dealing with the issue this  court  in  Ambika  '
#                    'Prasad  Mishra  v.\n'
#                    '    State of U.P. & Anr., AIR 1980 SC 1762, held as under:',
#                    '81.    The view has been expressed by a three-Judge Bench '
#                    'of this  Court  in\n'
#                    '    these very proceedings while dismissing the special '
#                    'leave petitions  of\n'
#                    '    Subhash Juneja and Harish Lal Singh vide order  dated  '
#                    '23.4.2003.  This\n'
#                    '    court applied the doctrine of finality of judgment and '
#                    'res-judicata and\n'
#                    '    refused to reopen these very proceedings.',
#                    '82.   Mrs. Kiran Suri, learned counsel appearing  for  '
#                    'the  respondent,  put\n'
#                    '    heavy reliance on a decision of this Court  in  the  '
#                    'case  of   Mathura\n'
#                    '    Prasad Bajoo Jaiswal & Ors. v. Dossibai N.B.  '
#                    'Jeejeebhoy,  (1970)1  SCC\n'
#                    '    613, for the proposition that question relating to the '
#                    'jurisdiction  of\n'
#                    '    a court cannot  be  deemed  to  have  been  finally  '
#                    'determined  by  an\n'
#                    '    erroneous decision of the court.  Further by an '
#                    'erroneous  decision  if\n'
#                    '    the court resumes jurisdiction which it  does  not  '
#                    'possess  under  the\n'
#                    '    Statute, the question cannot operate as res judicata '
#                    'between  the  same\n'
#                    '    parties whether the cause of action in  the  '
#                    'subsequent  litigation  is\n'
#                    '    same or otherwise.  In our opinion, the aforesaid  '
#                    'decision  is  of  no\n'
#                    '    help to the respondent for the simple reason that the '
#                    'facts and the law\n'
#                    '    involved in the instant case and the earlier round  '
#                    'of  litigation  are\n'
#                    '    the same.  In para 5 of the aforesaid judgment,  this  '
#                    'Court  has  laid\n'
#                    '    down the principle, which reads as under:-',
#                    '83. In the case arising out of these very proceedings '
#                    'reported in  Union  of\n'
#                    '    India & Ors. v. Ranbir Singh Rathaur & Ors., (2006) '
#                    '11  SCC  696,  this\n'
#                    '    Court held:',
#                    'a) That review of  the  earlier  orders  passed  by  this  '
#                    'court  was\n'
#                    '          "impermissible": approach of the High Court of '
#                    'reopening the  case\n'
#                    '          was "erroneous"; the issue of maintainability of '
#                    'the petitions was\n'
#                    '          of paramount importance:',
#                    'b) The finding recorded by the High Court that the entire '
#                    'record  was\n'
#                    '          not produced by the Union of India was not '
#                    'factually correct;',
#                    'c) To say that "justice  stood  at  the  higher  '
#                    'pedestal"  then  the\n'
#                    '          finality of litigation was not an answer  '
#                    'enabling  the  court  to\n'
#                    '          reopen a finally decided case;',
#                    '(d) Persons behind the false implication  were  not  '
#                    'impleaded  as\n'
#                    '              parties; and',
#                    '(e) Newspaper reports/statement made by any officer could  '
#                    'not  be\n'
#                    '              considered as evidence.',
#                    '84.  Violation of Fundamental Rights guaranteed under the '
#                    'Constitution  have\n'
#                    '      to be protected, but at the same time, it is the '
#                    'duty of the court  to\n'
#                    '      ensure that the decisions rendered by the  court  '
#                    'are  not  overturned\n'
#                    '      frequently,  that  too,  when  challenged  '
#                    'collaterally  as  that  was\n'
#                    '      directly  affecting  the   basic   structure   of   '
#                    'the   Constitution\n'
#                    '      incorporating the power of judicial review of this '
#                    'Court. There is  no\n'
#                    '      doubt that this Court has an extensive power to '
#                    'correct an error or to\n'
#                    '      review its decision but that cannot be done at the '
#                    'cost of doctrine of\n'
#                    '      finality. An issue of law can be overruled later on, '
#                    'but a question of\n'
#                    '      fact or, as in the present  case,  the  dispute  '
#                    'with  regard  to  the\n'
#                    '      termination of services cannot be reopened once it  '
#                    'has  been  finally\n'
#                    '      sealed in proceedings inter-se between the parties '
#                    'up  to  this  Court\n'
#                    '      way back in 1980.',
#                    '85.   The term ‘dismissal’ in the original  order  was  '
#                    'substituted  by  the\n'
#                    '      term  ‘termination’  issuing  the  corrigendum  to  '
#                    'ratify  a  mistake\n'
#                    '      committed while issuing the order. In fact,  the  '
#                    'competent  authority\n'
#                    '      had taken a decision only to terminate, and  '
#                    'therefore  it  was  found\n'
#                    '      necessary  to  issue  the  corrigendum.  However,  '
#                    'in  view  of   such\n'
#                    '      substitution of word ‘dismissal’ by the term '
#                    '‘termination’,  does  not\n'
#                    '      tilt the balance in favour of the respondents. More '
#                    'so, as pointed out\n'
#                    '      by Mr. Paras Kuhad, learned ASG that the  proposed  '
#                    '5%  deduction  had\n'
#                    '      been withdrawn, and therefore the issue did not '
#                    'survive.',
#                    '86.   Analysing entire facts of the case and the material '
#                    'produced in  Court\n'
#                    '      and upon an exhaustive consideration of the  '
#                    'matter,  we  are  of  the\n'
#                    '      definite opinion that the power of pleasure '
#                    'exercised by the President\n'
#                    '      in terminating the services of the respondents does  '
#                    'not  suffer  from\n'
#                    '      any illegality, bias or malafide or  based  on  any  '
#                    'other  extraneous\n'
#                    '      ground, and the same cannot be challenged on the '
#                    'ground that it  is  a\n'
#                    '      camouflage.  As discussed above,  the  onus  lay  '
#                    'on  the  respondent-\n'
#                    '      officers who alleged malafides.   No  credible  '
#                    'evidence  or  material\n'
#                    '      produced before the Court impels us to come to the '
#                    'conclusion that the\n'
#                    '      order of termination is baseless or malafide.',
#                    '87.  For the reasons aforesaid, these appeals are allowed '
#                    'and  the  judgment\n'
#                    '    and order passed by  the  Delhi  High  Court  is  set  '
#                    'aside.   Ordered\n'
#                    '    accordingly. No costs.',
#                    '…………………………….J.',
#                    '(Dr.  B.S.',
#                    'Chauhan)\n'
#                    '\n'
#                    '\n'
#                    '\n'
#                    '                                                              '
#                    '…………………………….J.',
#                    '(J.',
#                    'Chelameswar)\n'
#                    '\n'
#                    '\n'
#                    '                                                              '
#                    '…………………………….J.',
#                    '(M.Y.',
#                    'Eqbal)\nNew Delhi,\nMarch 6, 2014.',
#                    '-----------------------'],
#  'doc_title': 'Union Of India And Ors vs Major S.P. Sharma And Ors on 6 March, '
#               '1947'}

# %%
### clean judgement text


def format_judgement(doc_judgement: list) -> str:
    formatted_text = ''.join(tmp_json_data['doc_judgement']).replace('\n', ' ').replace('\r', '')\
                    .replace('  ', ' ').replace('   ', '')
    return formatted_text


def add_clean_judgement_text(json_file_path: str) -> dict:
    with open(json_file_path, 'rb') as f:
        json_data = json.load(f)
    json_data['clean_judgement'] = format_judgement(json_data['doc_judgement'])
    return json_data

## exec

write_jsons_at = '../data/processed/p_jsons'

for json_file in os.listdir(os.path.join(base_data_path, 'jsons')):
    json_file_path = os.path.join(base_data_path, 'jsons', json_file)
    processed_json_data = add_clean_judgement_text(json_file_path)
    with open(os.path.join(write_jsons_at, json_file), 'w') as f:
        json.dump(processed_json_data, f)
    print(f'Processed and saved: {json_file}')
# Out:
# Processed and saved: 103.json
# Processed and saved: 20.json
# Processed and saved: 98.json
# Processed and saved: 77.json
# Processed and saved: 61.json
# Processed and saved: 36.json
# Processed and saved: 41.json
# Processed and saved: 16.json
# Processed and saved: 57.json
# Processed and saved: 94.json
# Processed and saved: 82.json
# Processed and saved: 6.json
# Processed and saved: 7.json
# Processed and saved: 83.json
# Processed and saved: 95.json
# Processed and saved: 56.json
# Processed and saved: 17.json
# Processed and saved: 40.json
# Processed and saved: 37.json
# Processed and saved: 60.json
# Processed and saved: 99.json
# Processed and saved: 76.json
# Processed and saved: 21.json
# Processed and saved: 102.json
# Processed and saved: 47.json
# Processed and saved: 10.json
# Processed and saved: 51.json
# Processed and saved: 92.json
# Processed and saved: 84.json
# Processed and saved: 105.json
# Processed and saved: 26.json
# Processed and saved: 71.json
# Processed and saved: 88.json
# Processed and saved: 67.json
# Processed and saved: 30.json
# Processed and saved: 31.json
# Processed and saved: 89.json
# Processed and saved: 66.json
# Processed and saved: 70.json
# Processed and saved: 27.json
# Processed and saved: 104.json
# Processed and saved: 85.json
# Processed and saved: 93.json
# Processed and saved: 50.json
# Processed and saved: 11.json
# Processed and saved: 46.json
# Processed and saved: 69.json
# Processed and saved: 86.json
# Processed and saved: 90.json
# Processed and saved: 28.json
# Processed and saved: 53.json
# Processed and saved: 12.json
# Processed and saved: 45.json
# Processed and saved: 32.json
# Processed and saved: 65.json
# Processed and saved: 73.json
# Processed and saved: 24.json
# Processed and saved: 107.json
# Processed and saved: 49.json
# Processed and saved: 48.json
# Processed and saved: 106.json
# Processed and saved: 25.json
# Processed and saved: 72.json
# Processed and saved: 64.json
# Processed and saved: 33.json
# Processed and saved: 44.json
# Processed and saved: 13.json
# Processed and saved: 52.json
# Processed and saved: 29.json
# Processed and saved: 91.json
# Processed and saved: 68.json
# Processed and saved: 87.json
# Processed and saved: 34.json
# Processed and saved: 63.json
# Processed and saved: 8.json
# Processed and saved: 75.json
# Processed and saved: 22.json
# Processed and saved: 59.json
# Processed and saved: 101.json
# Processed and saved: 18.json
# Processed and saved: 38.json
# Processed and saved: 80.json
# Processed and saved: 79.json
# Processed and saved: 96.json
# Processed and saved: 55.json
# Processed and saved: 14.json
# Processed and saved: 43.json
# Processed and saved: 42.json
# Processed and saved: 15.json
# Processed and saved: 54.json
# Processed and saved: 78.json
# Processed and saved: 97.json
# Processed and saved: 81.json
# Processed and saved: 39.json
# Processed and saved: 19.json
# Processed and saved: 58.json
# Processed and saved: 100.json
# Processed and saved: 23.json
# Processed and saved: 74.json
# Processed and saved: 62.json
# Processed and saved: 9.json
# Processed and saved: 35.json
